# %% [markdown]
# <a href="https://colab.research.google.com/github/kiobov/Analytics/blob/master/Orders.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Data Cleaning Issues log [Issues log](https://onedrive.live.com/personal/c5b780b1a18b3f56/_layouts/15/doc2.aspx?sourcedoc=%7Be79bf710-e38d-45d2-a0b5-cd5373744235%7D&action=edit&wdinitialsession=f3dbbe3d-787a-4f19-9f4a-5d40c33267f5&wdrldsc=3&wdrldc=1&wdrldr=ReloadInEditMode%2CTransitionNonMetro%2COnSaveAsWebMet)

# %%
df = pd.read_csv("OrdersDataset.csv")
df.head()
# Out:
#      Order Id Product Id          Product Name         Region Country Code  \
# 0  ORD1000000    PROD106      External Storage    Middle East          UAE
# 1  ORD1000001    PROD100                   PS5   Asia Pacific           AU
# 2  ORD1000002    PROD103   Dell gaming laptop             NaN           BR
# 3  ORD1000003    PROD102           XboxSeriesX  North America       Mexico
# 4  ORD1000004    PROD106          1TB Storage    Middle East            SA
#
#   Marketing Channel Purchase Platform Account Creation Method Purchase Ts  \
# 0           partner          walmart                      NaN   7/14/2023
# 1           Online             Amazon                  Social    8/9/2023
# 2        mobile app              eBay                   Email   3/28/2019
# 3         In-Store             amazon                     NaN    2/8/2019
# 4        mobile app            Direct                   Email  2023-07-21
#
#                  Created On                   Ship Ts  \
# ...
